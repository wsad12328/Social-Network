# %%
import networkx as nx
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch_geometric.nn as pyg_nns
import torch_geometric.utils as pyg_utils
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.data import Data
import igraph as ig
from torch_geometric.utils import degree
from torch_geometric.loader import DataLoader
from utils.Generate_Synthetic import Generate_Synthetic
from DrBC import DrBC
from tqdm import tqdm
import numpy as np


NUM_MIN = 100
NUM_MAX = 200
Max_Eposide = 500
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)
# Out:
# Device: cuda

# %%
# 產生並儲存訓練圖
train_graphs = [Generate_Synthetic(NUM_MIN, NUM_MAX, seed+1000) for seed in range(1000)]
torch.save(train_graphs, f"../Data/Synthetic_Train/{NUM_MIN}-{NUM_MAX}_epoch_0001-5000.pt")

# 產生並儲存測試圖
test_graphs = [Generate_Synthetic(NUM_MIN, NUM_MAX, seed+2000) for seed in range(100)]
torch.save(test_graphs, f"../Data/Synthetic_Validation/{NUM_MIN}-{NUM_MAX}_epoch_5001-10000.pt")

# %%
# Initialize the model
model = DrBC(dim=128, num_layers=5, aggregate_type='sum').to(device)

# Optimizer for the model
optimizer = optim.Adam(model.parameters(), lr=0.0001)

loss = None

# Load the training graphs
graphs = torch.load(f"../Data/Synthetic_Train/{NUM_MIN}-{NUM_MAX}_graphs.pt", weights_only=False)
print("Loaded training graphs:", len(graphs))
# Create a DataLoader for the training graphs
loader = DataLoader(graphs, batch_size=16, shuffle=True)

for i in range(Max_Eposide):
    # Generate New Graphs
    # if i % 5000 == 0:
    #     graphs = [Generate_Synthetic(NUM_MIN, NUM_MAX, seed+1000) for seed in range(1000)]

    avg_loss = 0
    # Training Loop
    for batch in tqdm(loader):
        batch = batch.to(device)
        optimizer.zero_grad()
        
        # Calculate norm for the entire graph
        row, col = batch.edge_index
        deg = degree(row, batch.x.size(0), dtype=batch.x.dtype)
        deg_inv_sqrt = 1.0 / torch.sqrt(deg + 1)
        norm = deg_inv_sqrt[row] * deg_inv_sqrt[col]

        out = model(batch, norm)
        loss = F.binary_cross_entropy_with_logits(out, torch.sigmoid(batch.y))
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()
    avg_loss /= len(loader)
    print(f"Epoch {i+1}/{Max_Eposide}, Loss: {avg_loss:.4f}")

# Save the model
torch.save({'model_state_dict': model.state_dict()}, "../Model/DrBC_model.pth")
print("Model saved successfully.")
# Out:
# Loaded training graphs: 1000
# 100%|██████████| 63/63 [00:00<00:00, 104.01it/s]
# Epoch 1/500, Loss: 0.6932
# 100%|██████████| 63/63 [00:00<00:00, 70.93it/s]
# Epoch 2/500, Loss: 0.6931
# 100%|██████████| 63/63 [00:00<00:00, 87.22it/s]
# Epoch 3/500, Loss: 0.6931
# 100%|██████████| 63/63 [00:00<00:00, 95.28it/s]
# Epoch 4/500, Loss: 0.6931
# 100%|██████████| 63/63 [00:00<00:00, 71.35it/s]
# Epoch 5/500, Loss: 0.6931
# 100%|██████████| 63/63 [00:00<00:00, 107.99it/s]
# Epoch 6/500, Loss: 0.6931
# 100%|██████████| 63/63 [00:00<00:00, 82.55it/s]
# Epoch 7/500, Loss: 0.6931
# 100%|██████████| 63/63 [00:00<00:00, 76.10it/s]
# Epoch 8/500, Loss: 0.6931
# 100%|██████████| 63/63 [00:00<00:00, 131.72it/s]
# Epoch 9/500, Loss: 0.6931
# 100%|██████████| 63/63 [00:00<00:00, 76.04it/s]
# Epoch 10/500, Loss: 0.6931
# 100%|██████████| 63/63 [00:00<00:00, 92.69it/s]
# Epoch 11/500, Loss: 0.6931
# 100%|██████████| 63/63 [00:00<00:00, 131.75it/s]
# Epoch 12/500, Loss: 0.6931
# ...

# %%
# Testing with Top-K Accuracy
def top_k_accuracy(pred, true, k_percentage=1):
    pred = pred.cpu().detach().numpy().flatten()
    true = true.cpu().detach().numpy().flatten()
    
    # Calculate the number of top-k elements based on the percentage
    k = int(len(pred) * k_percentage / 100)  # Convert percentage to actual count
    
    # Get the top-k predicted and true values
    top_k_pred = np.argsort(-pred)[:k]
    top_k_true = np.argsort(-true)[:k]
    
    return len(set(top_k_pred) & set(top_k_true)) / k

# Load the test graphs
test_graphs = torch.load(f"../Data/Synthetic_Validation/{NUM_MIN}-{NUM_MAX}_graphs.pt", weights_only=False)
print("Loaded test graphs:", len(test_graphs))
# Create a DataLoader for the test graphs
test_loader = DataLoader(test_graphs, batch_size=32, shuffle=False)

total_top_k_acc = 0
num_batches = 0

K = 10  # Top-K percentage
# Load Model for Evaluation
model = DrBC(dim=128, num_layers=5, aggregate_type='sum').to(device)
checkpoint = torch.load("../Model/DrBC_model.pth", weights_only=True)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
print("Model loaded successfully.")

with torch.no_grad():
    for batch in tqdm(test_loader):
        batch = batch.to(device)
        row, col = batch.edge_index
        deg = degree(row, batch.x.size(0), dtype=batch.x.dtype)
        deg_inv_sqrt = 1.0 / torch.sqrt(deg + 1)
        norm = deg_inv_sqrt[row] * deg_inv_sqrt[col]

        pred_bc = model(batch, norm)
        top_k_acc = top_k_accuracy(pred_bc, batch.y, k_percentage=K)
        total_top_k_acc += top_k_acc
        num_batches += 1

final_acc = total_top_k_acc / num_batches
print(f"Final Top-{K} Accuracy: {final_acc:.4f}")
# Out:
# Loaded test graphs: 100
# Model loaded successfully.
# 100%|██████████| 4/4 [00:00<00:00, 200.45it/s]
# Final Top-10 Accuracy: 0.9210
