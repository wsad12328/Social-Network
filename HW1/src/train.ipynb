# %%
import networkx as nx
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch_geometric.nn as pyg_nns
import torch_geometric.utils as pyg_utils
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.data import Data
import igraph as ig

# %%
from utils.Generate_Synthetic import Generate_Synthetic
from torch_geometric.utils import degree
from DrBC import DrBC
from tqdm import tqdm
import torch

Max_Eposide = 1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)

for i in range(Max_Eposide):

    # Generate synthetic data and move to device
    Synthetic_Data = Generate_Synthetic()
    Synthetic_Data = Synthetic_Data.to(device)

    # Initialize the model
    model = DrBC(dim=128, num_layers=5).to(device)

    # Calculate norm for the entire graph
    row, col = Synthetic_Data.edge_index
    deg = degree(row, Synthetic_Data.x.size(0), dtype=Synthetic_Data.x.dtype)
    deg_inv_sqrt = 1.0 / torch.sqrt(deg + 1)
    norm = deg_inv_sqrt[row] * deg_inv_sqrt[col]

    # Forward pass through the model for the entire graph
    output = model(Synthetic_Data, norm)

    # Print the shape of the output and ensure it matches the number of nodes
    print(f"Output shape: {output.shape}")
    print(f"Number of nodes: {Synthetic_Data.num_nodes}")

    # Ensure the output contains BC values for all nodes
    assert output.shape[0] == Synthetic_Data.num_nodes, "Output shape does not match the number of nodes!"
# Out:
# Device: cuda
# torch.Size([5000, 1])
# Output shape: torch.Size([5000, 1])
# Number of nodes: 5000
