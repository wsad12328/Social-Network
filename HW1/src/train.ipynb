# %%
import networkx as nx
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch_geometric.nn as pyg_nns
import torch_geometric.utils as pyg_utils
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.data import Data
import igraph as ig

# %%
from utils.Generate_Synthetic import Generate_Synthetic
from torch_geometric.utils import degree
from DrBC import DrBC
from tqdm import tqdm
import torch

Max_Eposide = 200
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)

# Initialize the model
model = DrBC(dim=256, num_layers=3).to(device)

# Optimizer for the model
optimizer = optim.Adam(model.parameters())

for i in range(Max_Eposide):

    # Generate synthetic data and move to device
    Synthetic_Data = Generate_Synthetic(seed=i)
    Synthetic_Data = Synthetic_Data.to(device)

    # Calculate norm for the entire graph
    row, col = Synthetic_Data.edge_index
    deg = degree(row, Synthetic_Data.x.size(0), dtype=Synthetic_Data.x.dtype)
    deg_inv_sqrt = 1.0 / torch.sqrt(deg + 1)
    norm = deg_inv_sqrt[row] * deg_inv_sqrt[col]

    # 1. 隨機抽取 25000 對節點對 (node_pairs)
    num_nodes = Synthetic_Data.num_nodes  # 總共的節點數 (假設 5000)
    total_pairs = num_nodes*5  # 我們要處理 25000 對點
    node_pairs = torch.randint(0, num_nodes, (total_pairs, 2), device=device)  # 隨機抽取節點對

    batch_size = 2500  # 每次 forward & backward 的批次大小
    epoch_loss = 0  # 初始化 epoch 的 loss 變數


    # 2. 以 batch_size = 16 來進行 forward & backward
    for batch_start in range(0, total_pairs, batch_size):
        batch_end = min(batch_start + batch_size, total_pairs)  # 確保不超過 25000 個點對
        batch_node_pairs = node_pairs[batch_start:batch_end]

        # 取得這一批的點的 Betweenness Centrality (BC)
        real_BC = Synthetic_Data.y[batch_node_pairs]  # 這批點的真實 BC

        b_ij = real_BC[:, 0] - real_BC[:, 1]  # 計算 BC 差值 (ground truth)

        # Forward：對這一批的點做預測
        Predict_BC = model(Synthetic_Data, norm)  # 計算整張圖的 BC
        Batch_Predict_BC = Predict_BC[batch_node_pairs]
        y_ij = Batch_Predict_BC[:, 0] - Batch_Predict_BC[:, 1]  # 計算 BC 差值 (預測值)
        
        # z-score normalization
        # y_ij = (y_ij - y_ij.mean()) / y_ij.std()
        # b_ij = (b_ij - b_ij.mean()) / b_ij.std()

        # Loss：計算這一批的 loss
        loss = F.binary_cross_entropy_with_logits(y_ij, torch.sigmoid(b_ij))  # 使用二元交叉熵損失函數
        epoch_loss += loss.item()  # 將本次 batch 的 loss 加入 epoch_loss

        optimizer.zero_grad()  # 清除舊梯度
        loss.backward()  # 反向傳播
        optimizer.step()  # 更新模型參數


    # 打印每個 epoch 的 total loss
    print(f"Epoch {i + 1}/{Max_Eposide}, Loss: {epoch_loss / (total_pairs / batch_size)}")
        # 打印梯度 (可選)
        # for name, param in model.named_parameters():
        #     if param.grad is not None:
        #         print(f"{name} grad norm: {param.grad.norm()}")

# save the model

torch.save(model.state_dict(), 'model.pth')
# Out:
# Device: cuda
# Epoch 1/200, Loss: 0.6931643903255462
# Epoch 2/200, Loss: 0.6931471168994904
# Epoch 3/200, Loss: 0.6931459784507752
# Epoch 4/200, Loss: 0.6931456387042999
# Epoch 5/200, Loss: 0.693145501613617
# Epoch 6/200, Loss: 0.6931455671787262

# %%
import matplotlib.pyplot as plt
import torch
from torch_geometric.utils import degree

# Load the model
model = DrBC(dim=128, num_layers=5).to(device)
model.load_state_dict(torch.load('model.pth', weights_only=True))
model.eval()  # Set model to evaluation mode

# Initialize variables to store the accuracy values
top_1_acc_list = []
top_5_acc_list = []

# Generate 100 synthetic graphs
for i in range(100):
    # Generate synthetic data and move to device
    Synthetic_Data = Generate_Synthetic(i)
    Synthetic_Data = Synthetic_Data.to(device)

    # Calculate norm for the entire graph
    row, col = Synthetic_Data.edge_index
    deg = degree(row, Synthetic_Data.x.size(0), dtype=Synthetic_Data.x.dtype)
    deg_inv_sqrt = 1.0 / torch.sqrt(deg + 1)
    norm = deg_inv_sqrt[row] * deg_inv_sqrt[col]

    # Forward pass: Calculate BC for the entire graph
    Predict_BC = model(Synthetic_Data, norm)

    # Get the true BC values
    real_BC = Synthetic_Data.y

    # Calculate Top-1% and Top-5% accuracy
    top_1 = int(len(real_BC) * 0.01)
    top_5 = int(len(real_BC) * 0.05)

    # Sort the predicted BC values in descending order
    _, indices = torch.sort(Predict_BC, descending=True)

    # Get the top 1% and top 5% predicted indices
    top_1_pred = indices[:top_1]
    top_5_pred = indices[:top_5]

    # Get the top 1% and top 5% real BC
    
    _, indices_real = torch.sort(real_BC, descending=True)
    top_1_real = indices_real[:top_1]
    top_5_real = indices_real[:top_5]    

    # Calculate the accuracy
    top_1_acc = (top_1_pred == top_1_real).float().mean().item()
    top_5_acc = (top_5_pred == top_5_real).float().mean().item()
    top_1_acc_list.append(top_1_acc)
    top_5_acc_list.append(top_5_acc)
    print(f"Graph {i+1}: Top-1% accuracy: {top_1_acc:.4f}, Top-5% accuracy: {top_5_acc:.4f}")   
    

# Plot the results
plt.plot(range(1, 101), top_1_acc_list, label='Top-1% accuracy')
plt.plot(range(1, 101), top_5_acc_list, label='Top-5% accuracy')
# Out:
# Graph 1: Top-1% accuracy: 0.4600, Top-5% accuracy: 0.1440
# Graph 2: Top-1% accuracy: 0.3600, Top-5% accuracy: 0.1200
# Graph 3: Top-1% accuracy: 0.4400, Top-5% accuracy: 0.1640
# Graph 4: Top-1% accuracy: 0.3200, Top-5% accuracy: 0.1200
# Graph 5: Top-1% accuracy: 0.4600, Top-5% accuracy: 0.1560
# Graph 6: Top-1% accuracy: 0.5400, Top-5% accuracy: 0.1880
# Graph 7: Top-1% accuracy: 0.5000, Top-5% accuracy: 0.1480
# Graph 8: Top-1% accuracy: 0.2600, Top-5% accuracy: 0.1240
# Graph 9: Top-1% accuracy: 0.6200, Top-5% accuracy: 0.1800
# Graph 10: Top-1% accuracy: 0.4400, Top-5% accuracy: 0.1760
# Graph 11: Top-1% accuracy: 0.3400, Top-5% accuracy: 0.1400
# Graph 12: Top-1% accuracy: 0.2800, Top-5% accuracy: 0.1040
# Graph 13: Top-1% accuracy: 0.4000, Top-5% accuracy: 0.1040
# Graph 14: Top-1% accuracy: 0.2600, Top-5% accuracy: 0.1200
# Graph 15: Top-1% accuracy: 0.7000, Top-5% accuracy: 0.2160
# Graph 16: Top-1% accuracy: 0.4600, Top-5% accuracy: 0.1280
# ...
